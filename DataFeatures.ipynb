# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#FUNCTION FOR PROVIDING FEATURE SUMMARY
def DataFrameAnalysis(df_fa):
    print('DataFrame shape')
    print('rows:',df_fa.shape[0])
    print('cols:',df_fa.shape[1])
    col_list=['Null','%Null','Unique_Count','Data_type','Max/Min','Mean','Std','Skewness','Sample_values']
    df=pd.DataFrame(index=df_fa.columns,columns=col_list)
    df['Null']=list([len(df_fa[col][df_fa[col].isnull()]) for i,col in enumerate(df_fa.columns)])
    df['%_Null']=list([len(df_fa[col][df_fa[col].isnull()])/df_fa.shape[0]*100 for i,col in enumerate(df_fa.columns)])
    df['Unique_Count']=list([len(df_fa[col].unique()) for i,col in enumerate(df_fa.columns)])
    df['Data_type']=list([df_fa[col].dtype for i,col in enumerate(df_fa.columns)])
    for i,col in enumerate(df_fa.columns):
        if 'float' in str(df_fa[col].dtype) or 'int' in str(df_fa[col].dtype):
            df.at[col,'Max/Min']=str(round(df_fa[col].max(),2))+'/'+str(round(df_fa[col].min(),2))
            df.at[col,'Mean']=df_fa[col].mean()
            df.at[col,'Std']=df_fa[col].std()
            df.at[col,'Skewness']=df_fa[col].skew()
        df.at[col,'Sample_values']=list(df_fa[col].unique())
    return(df.fillna('-'))

# %%
df_train = pd.read_csv('test.csv')

# %%
DataFrameAnalysis(df_train)
# Out:
# DataFrame shape
# rows: 804684
# cols: 12
#                       Null %Null  Unique_Count Data_type  \
# channelGrouping          0     -             8    object
# date                     0     -           272     int64
# device                   0     -           243    object
# fullVisitorId            0     -        652237    object
# geoNetwork               0     -         36698    object
# sessionId                0     -        803863    object
# socialEngagementType     0     -             1    object
# totals                   0     -          3814    object
# trafficSource            0     -         52951    object
# visitId                  0     -        779504     int64
# visitNumber              0     -           446     int64
# visitStartTime           0     -        780264     int64
#
#                                     Max/Min         Mean        Std  \
# channelGrouping                           -            -          -
# date                      20180430/20170802   2.0175e+07     4573.1
# device                                    -            -          -
# fullVisitorId                             -            -          -
# geoNetwork                                -            -          -
# sessionId                                 -            -          -
# socialEngagementType                      -            -          -
# totals                                    -            -          -
# trafficSource                             -            -          -
# visitId               1525157818/1501656404  1.51334e+09  6.676e+06
# visitNumber                           457/1      2.41409    9.43174
# visitStartTime        1525157818/1501657203  1.51334e+09  6.676e+06
#
#                        Skewness  \
# channelGrouping               -
# date                   0.296963
# device                        -
# fullVisitorId                 -
# geoNetwork                    -
# sessionId                     -
# socialEngagementType          -
# totals                        -
# trafficSource                 -
# visitId               0.0375182
# visitNumber             22.1655
# visitStartTime        0.0375182
#
#                                                           Sample_values  \
# channelGrouping       [Organic Search, Paid Search, Display, Direct,...
# date                  [20171016, 20171130, 20180415, 20171110, 20171...
# device                [{"browser": "Chrome", "browserVersion": "not ...
# fullVisitorId         [6167871330617112363, 0643697640977915618, 605...
# geoNetwork            [{"continent": "Asia", "subContinent": "Southe...
# sessionId             [6167871330617112363_1508151024, 0643697640977...
# socialEngagementType                             [Not Socially Engaged]
# totals                [{"visits": "1", "hits": "4", "pageviews": "4"...
# trafficSource         [{"campaign": "(not set)", "source": "google",...
# visitId               [1508151024, 1508175522, 1508143220, 150819353...
# visitNumber           [2, 1, 6, 4, 22, 3, 17, 18, 5, 10, 14, 8, 102,...
# visitStartTime        [1508151024, 1508175522, 1508143220, 150819353...
#
#                       %_Null
# channelGrouping          0.0
# date                     0.0
# device                   0.0
# fullVisitorId            0.0
# geoNetwork               0.0
# sessionId                0.0
# socialEngagementType     0.0
# totals                   0.0
# trafficSource            0.0
# visitId                  0.0
# visitNumber              0.0
# visitStartTime           0.0
